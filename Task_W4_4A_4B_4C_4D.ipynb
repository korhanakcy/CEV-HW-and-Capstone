# %% [markdown]
# TASK-4A: Pleasse present a descriptive statistics analysis to provide a general understanding of the dataset. (Describe)

# %% [markdown]
# TASK-4B: Please prpvide the visual illustrations of the dataset that will demonstrate the insightful distribution with rspect to the target column (CDRGLOB: the level fo Alzgeimer Disease - AD)\
# TASK-4C: Please provide a correlation analysis between two different variables/features and argue for the analysis outputs.\
# TASK-4D: Please provide several pivot tables for insightful illustrations both via tables and figures.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Temporary_data3_-_Copy.xlsx")

# %%
TASK-4A

# %%
data.describe()
# Out:
#                SEX         EDUC     MARISTAT     INDEPEND     RESIDENC  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000
# mean      1.573855    15.223781     1.658789     1.316100     1.112999
# std       0.494698     3.418699     1.136754     0.598538     0.360372
# min       1.000000     0.000000     1.000000     1.000000     1.000000
# 25%       1.000000    12.000000     1.000000     1.000000     1.000000
# 50%       2.000000    16.000000     1.000000     1.000000     1.000000
# 75%       2.000000    18.000000     2.000000     2.000000     1.000000
# max       2.000000    25.000000     6.000000     4.000000     4.000000
#
#            NACCFAM      ANYMEDS      SMOKYRS      NACCTBI     DIABETES  ...  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000  ...
# mean      0.631462     0.952733     9.754801     0.127031     0.192762  ...
# std       0.482586     0.212289    14.351222     0.333131     0.432160  ...
# ...

# %% [markdown]
# TASK-4C

# %%
X = data["EDUC"]
Y = data["SMOKYRS"]
labels =  data["CDRGLOB"]

plt.scatter(X , Y, s=20, cmap = "viridis", c = labels, alpha = 0.5)
plt.xlabel("Education Year")
plt.ylabel("Smoking Year")
plt.title("Smoking and Education year")
plt.colorbar()
plt.show()

# %%
X = data["EDUC"]
Y = data["HIPPOVOL"]
labels =  data["CDRGLOB"]

plt.scatter(X , Y, s=20, cmap = "viridis", c = labels, alpha = 0.5)
plt.xlabel("Education Year")
plt.ylabel("HIPPOVOL")
plt.title("")
plt.colorbar()
plt.show()

# %%
X = data["NACCBMI"]
Y = data["HIPPOVOL"]
labels =  data["CDRGLOB"]

plt.scatter(X , Y, s=20, cmap = "viridis", c = labels, alpha = 0.5)
plt.xlabel("NACCBMI")
plt.ylabel("HIPPOVOL")
plt.title("")
plt.colorbar()
plt.show()

# %%
data.pivot_table("HIPPOVOL", index = ["CDRGLOB", "SEX"], columns = rsupfrm).plot(kind = "bar" )
plt.legend()

# %%
X = data["RSUPTEM"]
Y = data["HIPPOVOL"]
labels =  data["CDRGLOB"]

plt.scatter(X , Y, s=20, cmap = "viridis", c = labels, alpha = 0.5)
plt.xlabel("RSUPTEM")
plt.ylabel("HIPPOVOL")
plt.title("")
plt.colorbar()
plt.show()

# %% [markdown]
# TASK - 4C

# %%
data.corr()
# Out:
#                SEX      EDUC  MARISTAT  INDEPEND  RESIDENC   NACCFAM  \
# SEX       1.000000 -0.129742  0.244620 -0.098873  0.054726 -0.005097
# EDUC     -0.129742  1.000000 -0.021607 -0.108642 -0.030139  0.062121
# MARISTAT  0.244620 -0.021607  1.000000 -0.099897  0.101406 -0.034038
# INDEPEND -0.098873 -0.108642 -0.099897  1.000000  0.115258 -0.036503
# RESIDENC  0.054726 -0.030139  0.101406  0.115258  1.000000 -0.057857
# ...            ...       ...       ...       ...       ...       ...
# RSUPTEMM  0.057830  0.041457  0.083243 -0.359562  0.018632 -0.030018
# RSUPMAR  -0.231002  0.184778 -0.022053 -0.143379 -0.084733  0.087566
# RSUPMARM  0.040348  0.145529  0.019383 -0.189939  0.076612  0.074872
# RTRTEM   -0.148505  0.192072 -0.059230 -0.055922 -0.118758  0.114719
# RTRTEMM  -0.008018  0.193395 -0.044063 -0.042208 -0.117984  0.135564
#
#            ANYMEDS   SMOKYRS   NACCTBI  DIABETES  ...    RSUPFR   RSUPFRM  \
# ...

# %%
TASK - 4D

# %%
rsupfrm = pd.qcut(data["RSUPFRM"],2)
data.pivot_table("HIPPOVOL", index = "SEX", columns = rsupfrm)
# Out:
# RSUPFRM  (0.901, 2.198]  (2.198, 4.06]
# SEX
# 1              5.964692       6.410722
# 2              5.645997       6.018094

# %%
data.pivot_table("HIPPOVOL", index = "CDRGLOB", columns = rsupfrm, aggfunc = "count")
# Out:
# RSUPFRM  (0.901, 1.988]  (1.988, 2.198]  (2.198, 2.376]  (2.376, 4.06]
# CDRGLOB
# 0                    93             143             179            231
# 1                   154             134             121             87
# 2                    72              46              29             18
# 3                    20              16               8              3

# %%
data.pivot_table('HIPPOVOL',index=['CDRGLOB','EDUC'],columns=['APA'], aggfunc="mean")
# Out:
# APA                  0         1
# CDRGLOB EDUC
# 0       0     5.636200       NaN
#         3     6.099700       NaN
#         5     5.568350       NaN
#         6     6.384425       NaN
#         7     6.591850       NaN
# ...                ...       ...
# 3       15         NaN  6.022400
#         16    4.347200  4.601333
#         18    6.606700  4.587525
#         19    4.682000  5.551900
#         20    4.207067  5.939700
#
# [77 rows x 2 columns]
